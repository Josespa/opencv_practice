# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_path = "../resources/images/opencv-logo.png"
img = cv2.imread(img_path)
plt.imshow(img)

# %% [markdown]
# ## Creating GUI window to display an image on screen

# %%
cv2.imshow("image", img)
# To hold the window on screen, we use cv2.waitKey method
# Once it detected the close input, it will release the control
# To the next line
# First Parameter is for holding screen for specified milliseconds
# It should be positive integer. If 0 pass a parameter, then it will
# hold the screen until user close it.
cv2.waitKey(0)
 # It is for removing/deleting created GUI window from screen
# and memory
cv2.destroyAllWindows()

# %% [markdown]
# ### Write new image

# %%
new_img_path = "../resources/images/new_opencv_logo.jpg"
cv2.imwrite(new_img_path, img)
# Out:
# True

# %%
import os
# Size in bytes of a plain file; amount of data waiting on some special files.
os.stat(img_path).st_size
# Out:
# 24903

# %%
os.stat(new_img_path).st_size
# Out:
# 65659

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (739, 600, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img[10, 5]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
img[:, :, 0]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# Reading Videos
capture = cv2.VideoCapture("../resources/videos/dog.mp4")

while True:
    isTrue, frame = capture.read()    
    if isTrue:    
        cv2.imshow('Video', frame)
        if cv2.waitKey(20) & 0xFF==ord('q'):
            break            
    else:
        break
capture.release()
cv2.destroyAllWindows()
